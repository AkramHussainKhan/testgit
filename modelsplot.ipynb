# %% [markdown]
# <a href="https://colab.research.google.com/github/AkramHussainKhan/testgit/blob/main/modelsplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results = pd.DataFrame({'Model':['DT--Default Setting', 'DT--Manual Setting', 'DT--hyperparameter Tunned setting','RF--Default Setting', 'RF--Manual Setting', 'RF--hyperparameter Tunned setting','AB--Default Setting', 'AB--Manual Setting', 'AB--hyperparameter Tunned setting','GB--Default Setting', 'GB--Manual Setting', 'GB--hyperparameter Tunned setting'],
                        'Accuracy':[ 0.803313,0.795335,0.805193,0.808111,0.798563,0.713364,0.644927,0.628539,0.640946,0.803313,0.795335,0.805193],
                        'Precision':[0.766662, 0.852421,0.833427,0.832576,0.830004,0.744381,0.659468,0.638833,0.656476,0.836024,0.852344,0.837100],
                        'Recall':[0.795395,0.781477,0.800774,0.808064,0.798545,0.713488,0.644936,0.628570,0.640944,0.803318,0.795395,0.805157],
                        'F1 Score':[0.767094,0.792542,0.810785,0.816688,0.807081,0.701868,0.648691,0.623757,0.644635,0.812135,0.803596,0.815365],
                        'AUC':[0.872155,0.966808,0.973873,0.972858,0.966644,0.947891,0.888181,0.894799,0.888715,0.974907,0.971829,0.975222]
                        })

# %%
name = results['Model']
price = results['Accuracy']
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
# Horizontal Bar Plot
ax.barh(name, price,color ='maroon')
plt.xlim(0, 1,0.2)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
# Show top values
ax.invert_yaxis()
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.01, i.get_y()+0.5,
             str(round((i.get_width()), 4)),
             fontsize = 10, fontweight ='bold',
             color ='green')
 
# Add Plot Title
ax.set_title('Comparison of Predictive Machine Learning Models Based on Accuracy',
             loc ='center', )
ax.set_ylabel('Models', 
              fontweight ='bold')
ax.set_xlabel('Accuracy', 
              fontweight ='bold')

# Show Plot
plt.show()

# %% [markdown]
# Plot number one

# %%
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
#  Bar Plot
colors = plt.get_cmap('tab10').colors
plt.bar(results['Model'], results['Accuracy'],color = colors)
plt.ylim(0, 1,0.2)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 5)
plt.xticks(rotation=90)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Add annotation to bars
for bar in ax.patches:
  ax.annotate(format(bar.get_height(), '.4f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),color ='blue',
                   textcoords='offset points')
 
# Add Plot Title
ax.set_title('Comparison of Predictive Machine Learning Models Based on Accuracy',
             loc ='center', )
ax.set_ylabel('Accuracy', 
              fontweight ='bold')
ax.set_xlabel('Models', 
              fontweight ='bold')

# Show Plot
plt.show()

# %% [markdown]
# Plot number two

# %%
name = results['Model']
price = results['Precision']
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
#  Bar Plot
colors = plt.get_cmap('tab10').colors
plt.bar(name, price,color = colors)
plt.ylim(0, 1,0.2)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 5)
plt.xticks(rotation=90)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Add annotation to bars
for bar in ax.patches:
  ax.annotate(format(bar.get_height(), '.4f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
 
# Add Plot Title
ax.set_title('Comparison of Predictive Machine Learning Models Based on Precision',
             loc ='center', )
ax.set_ylabel('Precision', 
              fontweight ='bold')
ax.set_xlabel('Models', 
              fontweight ='bold')

# Show Plot
plt.show()

# %% [markdown]
# plot number 3

# %%
name = results['Model']
price = results['Recall']
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
#  Bar Plot
colors = plt.get_cmap('tab10').colors
plt.bar(name, price,color = colors)
plt.ylim(0, 1,0.2)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 5)
plt.xticks(rotation=90)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Add annotation to bars
for bar in ax.patches:
  ax.annotate(format(bar.get_height(), '.4f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
 
# Add Plot Title
ax.set_title('Comparison of Predictive Machine Learning Models Based on Recall',
             loc ='center', )
ax.set_ylabel('Recall', 
              fontweight ='bold')
ax.set_xlabel('Models', 
              fontweight ='bold')

# Show Plot
plt.show()

# %% [markdown]
# plot number 4

# %%
name = results['Model']
price = results['F1 Score']
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
#  Bar Plot
colors = plt.get_cmap('tab10').colors
plt.bar(name, price,color = colors)
plt.ylim(0, 1,0.2)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 5)
plt.xticks(rotation=90)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Add annotation to bars
for bar in ax.patches:
  ax.annotate(format(bar.get_height(), '.4f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
 
# Add Plot Title
ax.set_title('Comparison of Predictive Machine Learning Models Based on F1 Score',
             loc ='center', )
ax.set_ylabel('F1 Score', 
              fontweight ='bold')
ax.set_xlabel('Models', 
              fontweight ='bold')

# Show Plot
plt.show()

# %% [markdown]
# plot number 5

# %%
name = results['Model']
price = results['AUC']
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
#  Bar Plot
colors = plt.get_cmap('tab10').colors
plt.bar(name, price,color = colors)
plt.ylim(0, 1.2,0.2)
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 10)
ax.yaxis.set_tick_params(pad = 5)
plt.xticks(rotation=90)

# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)

# Add annotation to bars
for bar in ax.patches:
  ax.annotate(format(bar.get_height(), '.4f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
 
# Add Plot Title
ax.set_title('Comparison of Predictive Machine Learning Models Based on AUC',
             loc ='center', )
ax.set_ylabel('AUC', 
              fontweight ='bold')
ax.set_xlabel('Models', 
              fontweight ='bold')

# Show Plot
plt.show()
